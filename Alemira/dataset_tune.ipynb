# %%
import os
import numpy as np
import pandas as pd
import csv
from datetime import datetime
import plotly.express as px
from sklearn.feature_selection import VarianceThreshold
from warnings import simplefilter
import matplotlib.pyplot as plt
import configparser

# %%
# -- Functions

# %run functions.ipynb

# %%
# -- Init Configuration Parameters

# %run predict_notebook_sections/configuration.ipynb

# %%
# -- Load Training data

train_data_df = pd.read_csv(consolidated_data_set_file_path.format(data_set_code=train_data_set_code)).set_index("timestamp").fillna(0)
train_data_df.index = pd.to_datetime(train_data_df.index)
print(train_data_df.shape)

train_data_df = train_data_df.select_dtypes(include=['number'])
print(train_data_df.shape)
# Out:
# (20074, 4702)
# (20074, 4702)

# %%
# -- Load Prod data

prod_data_dfs = []
for data_set_code in data_sets_to_preprocess:
    print(data_set_code)
    
    df_tmp = pd.read_csv(consolidated_data_set_file_path.format(data_set_code=data_set_code)).set_index("timestamp").fillna(0)
    df_tmp.index = pd.to_datetime(df_tmp.index)
    df_tmp.sort_index(inplace=True)
    prod_data_dfs.append(df_tmp)
    print(df_tmp.shape)
# Out:
# linear-cpu-stress-userapi-051516
# (181, 4389)
# linear-cpu-stress-redis-091514
# /var/folders/9t/qlwpj28d5nb9pcvfgv1y9l480000gn/T/ipykernel_33911/3439951834.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_tmp.index = pd.to_datetime(df_tmp.index)
# (151, 5808)
# linear-memory-stress-userapi-051218
# (181, 4446)
# linear-memory-stress-redis-091522
# (151, 6015)
# linear-network-delay-userapi-051816
# (180, 4355)
# linear-network-delay-redis-092016
# (151, 5844)
# linear-cpu-stress-identity-100410
# (151, 6074)
# linear-cpu-stress-userhandlers-100517
# (151, 5858)
# linear-memory-stress-identity-100414
# (151, 5898)
# linear-memory-stress-userhandlers-100609
# (151, 6074)

# %%
# -- Aligh the prod datasets' column sets to the train dataset's column set
# We use outer_by_training_ds

if dataset_alignment_method == "outer_by_training_ds":
    
    for ii, data_set_code in enumerate(data_sets_to_preprocess):

        # - Save the kpis not seen in prod
        
        kpis_not_seen_in_prod_names_transformed = tranform_kpi_names(list(set(train_data_df.columns) - set(prod_data_dfs[ii].columns)))
        # Create a target folder if does not exist
        create_dir(kpis_not_seen_in_prod_dir_path)
        with open(kpis_not_seen_in_prod_file_path.format(data_set_code=data_set_code), "w") as outfile:
            csv_writer = csv.writer(outfile)
            for row in kpis_not_seen_in_prod_names_transformed:
                csv_writer.writerow([row])
        
        train_data_df, prod_data_dfs[ii] = train_data_df.align(prod_data_dfs[ii], axis=1, join='left')
        print(data_set_code, ":", train_data_df.shape, prod_data_dfs[ii].shape)
        


if dataset_alignment_method == "intersection":
    for vv in range(2):
        for ii, data_set_code in enumerate(data_sets_to_preprocess):
            train_data_df, prod_data_dfs[ii] = train_data_df.align(prod_data_dfs[ii], axis=1, join='inner')
            print(data_set_code, ":", train_data_df.shape, prod_data_dfs[ii].shape)
# Out:
# linear-cpu-stress-userapi-051516 : (20074, 4702) (181, 4702)
# linear-cpu-stress-redis-091514 : (20074, 4702) (151, 4702)
# linear-memory-stress-userapi-051218 : (20074, 4702) (181, 4702)
# linear-memory-stress-redis-091522 : (20074, 4702) (151, 4702)
# linear-network-delay-userapi-051816 : (20074, 4702) (180, 4702)
# linear-network-delay-redis-092016 : (20074, 4702) (151, 4702)
# linear-cpu-stress-identity-100410 : (20074, 4702) (151, 4702)
# linear-cpu-stress-userhandlers-100517 : (20074, 4702) (151, 4702)
# linear-memory-stress-identity-100414 : (20074, 4702) (151, 4702)
# linear-memory-stress-userhandlers-100609 : (20074, 4702) (151, 4702)

# %%
# -- Transform the KPI names into the {ServiceName}_{MetricName} format
# We do it

# Get the tranformed column names
transformed_column_names = tranform_kpi_names(train_data_df.columns)

# Update dfs
train_data_df.columns = transformed_column_names
for ii in range(len(prod_data_dfs)):
    prod_data_dfs[ii].columns = transformed_column_names


train_data_df.head()
# Out:
#                      unknown-node_lm-UserCount  unknown-node_lm-Requests/s  \
# timestamp
# 2023-03-28 12:54:00                        1.0                    0.000000
# 2023-03-28 12:57:00                        1.0                    0.300000
# 2023-03-28 12:58:00                        1.0                    0.300000
# 2023-03-28 12:59:00                        1.0                    0.300000
# 2023-03-28 13:00:00                        1.0                    0.359016
#
#                      unknown-node_lm-Failures/s  unknown-node_lm-50%  \
# timestamp
# 2023-03-28 12:54:00                         0.0                180.0
# 2023-03-28 12:57:00                         0.0                  0.0
# 2023-03-28 12:58:00                         0.0                  0.0
# 2023-03-28 12:59:00                         0.0                  0.0
# 2023-03-28 13:00:00                         0.0               1700.0
#
#                      unknown-node_lm-66%  unknown-node_lm-75%  \
# timestamp
# 2023-03-28 12:54:00                180.0                180.0
# 2023-03-28 12:57:00                  0.0                  0.0
# 2023-03-28 12:58:00                  0.0                  0.0
# 2023-03-28 12:59:00                  0.0                  0.0
# 2023-03-28 13:00:00               1700.0               1700.0
#
#                      unknown-node_lm-80%  unknown-node_lm-90%  \
# timestamp
# 2023-03-28 12:54:00                180.0                180.0
# 2023-03-28 12:57:00                  0.0                  0.0
# 2023-03-28 12:58:00                  0.0                  0.0
# 2023-03-28 12:59:00                  0.0                  0.0
# 2023-03-28 13:00:00               1700.0               1700.0
#
#                      unknown-node_lm-95%  unknown-node_lm-98%  ...  \
# timestamp                                                      ...
# 2023-03-28 12:54:00                180.0                180.0  ...
# 2023-03-28 12:57:00                  0.0                  0.0  ...
# 2023-03-28 12:58:00                  0.0                  0.0  ...
# 2023-03-28 12:59:00                  0.0                  0.0  ...
# 2023-03-28 13:00:00               1700.0               1700.0  ...
#
#                      alms-core-rui-dcount_gm-64-count  \
# timestamp
# 2023-03-28 12:54:00                               0.0
# 2023-03-28 12:57:00                               0.0
# 2023-03-28 12:58:00                               0.0
# 2023-03-28 12:59:00                               0.0
# 2023-03-28 13:00:00                               0.0
#
#                      alms-core-rui-dcount_gm-64-firstquartile  \
# timestamp
# 2023-03-28 12:54:00                                       0.0
# 2023-03-28 12:57:00                                       0.0
# 2023-03-28 12:58:00                                       0.0
# 2023-03-28 12:59:00                                       0.0
# 2023-03-28 13:00:00                                       0.0
#
#                      alms-core-rui-dcount_gm-64-thirdquartile  \
# timestamp
# 2023-03-28 12:54:00                                       0.0
# 2023-03-28 12:57:00                                       0.0
# 2023-03-28 12:58:00                                       0.0
# 2023-03-28 12:59:00                                       0.0
# 2023-03-28 13:00:00                                       0.0
#
#                      alms-core-rui-dmean_gm-64-min  \
# timestamp
# 2023-03-28 12:54:00                            0.0
# 2023-03-28 12:57:00                            0.0
# 2023-03-28 12:58:00                            0.0
# 2023-03-28 12:59:00                            0.0
# 2023-03-28 13:00:00                            0.0
#
#                      alms-core-rui-dmean_gm-64-max  \
# timestamp
# 2023-03-28 12:54:00                            0.0
# 2023-03-28 12:57:00                            0.0
# 2023-03-28 12:58:00                            0.0
# 2023-03-28 12:59:00                            0.0
# 2023-03-28 13:00:00                            0.0
#
#                      alms-core-rui-dmean_gm-64-mean  \
# timestamp
# 2023-03-28 12:54:00                             0.0
# 2023-03-28 12:57:00                             0.0
# 2023-03-28 12:58:00                             0.0
# 2023-03-28 12:59:00                             0.0
# 2023-03-28 13:00:00                             0.0
#
#                      alms-core-rui-dmean_gm-64-median  \
# timestamp
# 2023-03-28 12:54:00                               0.0
# 2023-03-28 12:57:00                               0.0
# 2023-03-28 12:58:00                               0.0
# 2023-03-28 12:59:00                               0.0
# 2023-03-28 13:00:00                               0.0
#
#                      alms-core-rui-dmean_gm-64-count  \
# timestamp
# 2023-03-28 12:54:00                              0.0
# 2023-03-28 12:57:00                              0.0
# 2023-03-28 12:58:00                              0.0
# 2023-03-28 12:59:00                              0.0
# 2023-03-28 13:00:00                              0.0
#
#                      alms-core-rui-dmean_gm-64-firstquartile  \
# timestamp
# 2023-03-28 12:54:00                                      0.0
# 2023-03-28 12:57:00                                      0.0
# 2023-03-28 12:58:00                                      0.0
# 2023-03-28 12:59:00                                      0.0
# 2023-03-28 13:00:00                                      0.0
#
#                      alms-core-rui-dmean_gm-64-thirdquartile
# timestamp
# 2023-03-28 12:54:00                                      0.0
# 2023-03-28 12:57:00                                      0.0
# 2023-03-28 12:58:00                                      0.0
# 2023-03-28 12:59:00                                      0.0
# 2023-03-28 13:00:00                                      0.0
#
# [5 rows x 4702 columns]

# %%
# -- Create and save the prod data sets configuration from the experminetal log

# Load the experminetal log
df_experiment_log = pd.read_csv(failure_log)

# Parse the experminetal log
data_sets_configs = []
for data_set_idx, data_set_code in enumerate(data_sets_to_preprocess):

    if data_set_code in normal_data_sets:
        continue

    print(data_set_code)

    start_failure_time = round_time(df_experiment_log[df_experiment_log["folder_name"] == data_set_code]["failure_begin_timestamp"].iloc[0])
    disruption_minute = int(df_experiment_log[df_experiment_log["folder_name"] == data_set_code]["Disruption"].iloc[0])
    start_failure_minute = np.where(prod_data_dfs[data_set_idx].index == start_failure_time)[0][0]
    exp_duration = prod_data_dfs[data_set_idx].shape[0] - 1

    the_config = [data_set_code, exp_duration, start_failure_minute, disruption_minute]
    data_sets_configs.append(the_config)

# Save the prod data sets configuration
create_dir("/".join(data_sets_config_file_path.split("/")[:-1]))
with open(data_sets_config_file_path, 'w') as f:
    write = csv.writer(f)
    write.writerow(["code", "total", "fi_start", "fi_end"])
    write.writerows(data_sets_configs)
# Out:
# linear-cpu-stress-userapi-051516
# linear-cpu-stress-redis-091514
# linear-memory-stress-userapi-051218
# linear-memory-stress-redis-091522
# linear-network-delay-userapi-051816
# linear-network-delay-redis-092016
# linear-cpu-stress-identity-100410
# linear-cpu-stress-userhandlers-100517
# linear-memory-stress-identity-100414
# linear-memory-stress-userhandlers-100609

# %%
# -- Exclude from the training data set the rows where the workload is <= user_count_threshold
# We do it

if DROP_LOW_TRAFFIC_POINTS_FROM_TRAINING:
    print(DROP_LOW_TRAFFIC_POINTS_FROM_TRAINING)

    train_data_df = train_data_df[train_data_df[column_name_number_of_users] >= DROP_LOW_TRAFFIC_POINTS_THRESHOLD]
    for ii in range(len(prod_data_dfs)):
        prod_data_dfs[ii] = prod_data_dfs[ii][prod_data_dfs[ii][column_name_number_of_users] >= DROP_LOW_TRAFFIC_POINTS_THRESHOLD]
# Out:
# True

# %%
# -- Drop the constant columns
# We do it

if DROP_CONSTANT_SERIES:

    print(DROP_CONSTANT_SERIES)
    
    # - Collect the constant KPIs in a list

    constant_filter = VarianceThreshold(threshold=0.00001)
    constant_filter.fit(train_data_df)

    constant_columns = [
        column for column in train_data_df.columns
        if column not in train_data_df.columns[constant_filter.get_support()] 
        and column not in columns_to_exclude_from_constant_kpis_search
    ]
    columns_to_drop = list(set(constant_columns))

    print("Number of the constant columns:", len(columns_to_drop))
    for col_ in columns_to_drop:
        print(col_)

    # Drop the constant columns in training data
    train_data_df.drop(columns=columns_to_drop, inplace=True)

    # Drop the constant columns in prod data
    for ii in range(len(prod_data_dfs)):
        prod_data_dfs[ii].drop(columns=columns_to_drop, inplace=True)

    train_data_df.head()
# Out:
# True
# Number of the constant columns: 754
# ui_gm-7-max
# ui_gm-17-median
# scorm-fe_pm-14-mean
# alms-core-userhandlers_pm-22-firstquartile
# rabbitmq_gm-21-thirdquartile
# ui_pm-13-min
# gradeservice_gm-21-mean
# scormhandlers_gm-17-min
# ztool_gm-17-min
# author-react_pm-16-min
# alms-core-learner_pm-22-firstquartile
# author_gm-7-mean
# userapi_gm-17-min
# rui_pm-16-firstquartile
# author_gm-9-mean
# node-quantile:kubelet-pleg-relist-duration-seconds:histogram-quantile_pm-39-min
# author-react_gm-7-firstquartile
# fileapi_pm-13-firstquartile
# instance:node-network-receive-drop-excluding-lo:rate5m_pm-19-mean
# ui_pm-16-min
# rui_pm-16-thirdquartile
# ztool_pm-15-max
# ui_gm-11-mean
# learner_pm-14-thirdquartile
# rui_gm-7-firstquartile
# userhandlers_pm-13-thirdquartile
# author_pm-14-min
# learner_pm-14-mean
# identity_pm-14-mean
# scormhandlers_gm-21-thirdquartile
# scormhandlers_gm-16-min
# rui_pm-14-max
# ztool_pm-15-thirdquartile
# rui_gm-21-min
# alms-core-ztool_pm-22-median
# rabbitmq_gm-19-count
# redis_gm-19-min
# acmesolver_pm-13-count
# identityapi_pm-14-max
# mail-sender_gm-7-thirdquartile
# scormhandlers_gm-16-median
# alms-core-scorm-fe_pm-22-median
# rui_pm-13-median
# alms-core-rui_pm-24-min
# author_gm-11-firstquartile
# acmesolver_pm-4-count
# scormhandlers_pm-14-min
# alms-core-ztool_pm-24-median
# scormhandlers_gm-21-min
# scorm-fe_gm-7-thirdquartile
# scorm-fe_pm-15-max
# learner_gm-9-min
# ui_pm-15-min
# rui_gm-21-mean
# identityapi_pm-14-mean
# ui_pm-15-thirdquartile
# ui_gm-9-mean
# acmesolver_pm-5-min
# acmesolver_pm-6-thirdquartile
# ztool_pm-14-thirdquartile
# scorm-fe_pm-16-firstquartile
# scorm-fe_gm-17-mean
# scorm-fe_gm-21-median
# redis_gm-16-mean
# learner_pm-16-firstquartile
# userhandlers_pm-14-max
# author-react_pm-13-firstquartile
# userapi_pm-14-max
# userapi_pm-14-thirdquartile
# learner_gm-17-min
# author_gm-21-mean
# scorm-fe_gm-17-thirdquartile
# learner_pm-14-max
# acmesolver_pm-16-median
# mail-sender-web_pm-14-median
# ztool_gm-9-median
# scorm-fe_gm-17-median
# ztool_gm-9-min
# alms-core-ztool_pm-24-firstquartile
# author_gm-11-median
# identityapi_pm-14-thirdquartile
# gradeservice_gm-21-min
# alms-core-mail-sender_gm-51-count
# author_pm-13-mean
# gradeservice_pm-14-firstquartile
# scormhandlers_pm-13-firstquartile
# userhandlers_pm-13-mean
# node-vmstat-oom-kill_pm-41-min
# rabbitmq_gm-16-firstquartile
# scorm_gm-19-min
# acmesolver_pm-15-min
# ztool_pm-14-min
# gradeservice_pm-14-max
# mail-sender-web_pm-13-mean
# author_pm-15-median
# fileapi_pm-13-mean
# author_gm-21-thirdquartile
# ztool_gm-21-min
# node-procs-blocked_pm-37-min
# alms-core-identity_pm-22-median
# scorm-fe_gm-21-thirdquartile
# alms-core-ui_pm-24-min
# acmesolver_pm-5-firstquartile
# redis_gm-21-mean
# gradeservice_pm-13-min
# mail-sender-web_pm-13-median
# acmesolver_pm-8-median
# scorm_gm-21-max
# rui_pm-16-mean
# alms-core-ztool_pm-24-max
# mail-sender_gm-7-max
# author_gm-7-min
# ui_pm-14-thirdquartile
# alms-core-userapi_pm-22-median
# rabbitmq_gm-19-median
# scorm-fe_gm-7-min
# scormhandlers_gm-16-mean
# alms-core-fileapi_pm-22-min
# mail-sender_pm-13-median
# mail-sender_gm-17-min
# scormhandlers_pm-14-mean
# rabbitmq_gm-16-min
# alms-core-ui_pm-22-firstquartile
# scormhandlers_gm-9-median
# mail-sender-web_pm-13-min
# alms-core-scormhandlers_pm-22-median
# scorm-fe_gm-9-max
# scorm-fe_gm-21-firstquartile
# author_pm-13-min
# alms-core-ui_pm-24-max
# userapi_pm-13-thirdquartile
# author-react_pm-15-max
# author_pm-16-mean
# alms-core-author-react_pm-22-min
# alms-core-scorm-fe_pm-22-min
# learner_gm-9-median
# scormhandlers_gm-19-min
# learner_gm-7-thirdquartile
# alms-core-fileapi_pm-22-firstquartile
# userapi_pm-13-firstquartile
# userapi_pm-13-min
# ztool_pm-14-firstquartile
# scorm-fe_pm-15-median
# gradeservice_pm-14-median
# ui_pm-16-firstquartile
# alms-core-learner_pm-24-mean
# learner_pm-13-mean
# rui_gm-9-thirdquartile
# ui_pm-15-firstquartile
# alms-core-rui_pm-24-median
# rabbitmq_pm-13-firstquartile
# identityapi_gm-17-min
# author_gm-17-min
# alms-core-mail-sender_gm-50-median
# instance-device:node-disk-io-time-seconds:rate5m_pm-21-min
# ztool_pm-15-min
# userapi_gm-16-min
# author-react_gm-17-max
# learner_pm-13-thirdquartile
# rui_pm-13-mean
# alms-core-rui_pm-24-mean
# rui_gm-17-firstquartile
# scorm_pm-14-mean
# identityapi_gm-9-median
# scorm-fe_pm-16-median
# learner_gm-11-median
# userapi_gm-21-min
# ui_pm-16-thirdquartile
# author-react_pm-13-max
# mail-sender_pm-13-firstquartile
# userapi_pm-13-median
# acmesolver_pm-8-max
# acmesolver_pm-8-min
# alms-core-mail-sender-web_pm-22-firstquartile
# alms-core-scorm_pm-24-mean
# redis_gm-16-median
# userapi_gm-21-max
# acmesolver_pm-16-thirdquartile
# alms-core-ztool_pm-22-min
# author_gm-9-min
# learner_pm-13-median
# acmesolver_pm-5-thirdquartile
# author_gm-9-firstquartile
# acmesolver_pm-15-median
# ui_gm-9-firstquartile
# redis_gm-21-min
# alms-core-ztool_pm-22-firstquartile
# rabbitmq_gm-19-mean
# alms-core-gradeservice_pm-22-firstquartile
# redis_pm-13-max
# ztool_pm-13-median
# author_gm-11-min
# redis_pm-13-median
# fileapi_pm-13-max
# identityapi_pm-14-median
# acmesolver_pm-4-mean
# ui_gm-21-min
# scorm_gm-21-firstquartile
# acmesolver_pm-15-thirdquartile
# mail-sender_gm-21-min
# learner_pm-14-median
# scormhandlers_gm-21-median
# scorm_gm-21-thirdquartile
# gradeservice_gm-9-firstquartile
# rui_pm-16-max
# mail-sender_gm-7-firstquartile
# rui_gm-17-thirdquartile
# fileapi_pm-14-firstquartile
# alms-core-identityapi_pm-22-min
# rabbitmq_pm-13-min
# ui_gm-17-firstquartile
# ui_gm-21-thirdquartile
# identity_pm-13-median
# alms-core-rui_pm-22-min
# ztool_gm-21-thirdquartile
# acmesolver_pm-7-median
# mail-sender-web_pm-13-max
# author_pm-14-max
# acmesolver_pm-7-mean
# mail-sender-web_pm-14-mean
# acmesolver_pm-14-max
# alms-core-mail-sender_gm-50-count
# mail-sender_gm-7-min
# alms-core-scorm_pm-22-min
# ui_pm-15-mean
# scormhandlers_pm-14-thirdquartile
# identityapi_gm-9-firstquartile
# learner_pm-14-min
# author-react_gm-17-median
# acmesolver_pm-4-median
# rui_gm-16-min
# userhandlers_pm-14-thirdquartile
# ui_pm-14-median
# scormhandlers_pm-14-median
# acmesolver_pm-16-mean
# redis_gm-16-min
# author_pm-15-min
# learner_gm-11-mean
# learner_gm-11-thirdquartile
# ui_pm-15-max
# rabbitmq_pm-13-thirdquartile
# userapi_pm-14-min
# redis_pm-13-mean
# rui_gm-21-thirdquartile
# scorm-fe_gm-7-mean
# rui_gm-11-mean
# author-react_gm-11-mean
# rabbitmq_gm-19-max
# scorm-fe_gm-9-median
# rabbitmq_pm-13-max
# gradeservice_gm-9-max
# scorm_pm-13-firstquartile
# mail-sender-web_pm-13-firstquartile
# acmesolver_pm-16-max
# learner_gm-11-max
# rui_pm-16-min
# identityapi_gm-9-min
# author_pm-15-thirdquartile
# rabbitmq_gm-16-count
# scormhandlers_gm-16-firstquartile
# alms-core-mail-sender_gm-51-thirdquartile
# ztool_pm-15-firstquartile
# learner_pm-16-median
# author-react_pm-13-thirdquartile
# gradeservice_pm-14-min
# identity_pm-13-max
# alms-core-scorm_pm-22-median
# scormhandlers_gm-21-mean
# fileapi_gm-21-max
# ztool_pm-13-firstquartile
# scorm-fe_pm-15-thirdquartile
# learner_gm-21-median
# mail-sender-web_gm-21-median
# acmesolver_pm-5-max
# mail-sender_gm-21-median
# ztool_pm-14-max
# ui_gm-17-max
# scorm-fe_pm-14-thirdquartile
# author_pm-16-min
# instance:node-network-receive-drop-excluding-lo:rate5m_pm-19-thirdquartile
# peerless-column-365315_gm-37-min
# scorm-fe_gm-7-firstquartile
# scormhandlers_gm-9-max
# learner_gm-7-median
# rui_pm-14-median
# rui_gm-7-mean
# scorm-fe_gm-11-thirdquartile
# rabbitmq_gm-16-max
# ztool_gm-9-firstquartile
# ztool_gm-9-mean
# redis_gm-16-firstquartile
# fileapi_pm-13-min
# author_gm-21-min
# identity_pm-13-thirdquartile
# ztool_pm-13-mean
# rui_pm-14-mean
# scorm-fe_pm-15-firstquartile
# mail-sender_gm-7-count
# author-react_gm-11-min
# mail-sender_gm-17-count
# author_gm-11-mean
# learner_pm-16-max
# rui_gm-21-max
# scorm-fe_gm-11-max
# learner_gm-9-firstquartile
# scorm-fe_gm-17-firstquartile
# rui_gm-9-max
# learner_gm-21-mean
# author-react_gm-21-thirdquartile
# author-react_gm-11-thirdquartile
# alms-core-rui_pm-24-firstquartile
# scorm-fe_pm-13-mean
# userhandlers_pm-13-max
# mail-sender-web_gm-17-min
# acmesolver_pm-4-min
# identity_pm-14-max
# ui_gm-21-firstquartile
# acmesolver_pm-7-max
# alms-core-scorm_pm-24-firstquartile
# ui_gm-11-thirdquartile
# mail-sender_pm-13-thirdquartile
# scorm_pm-14-firstquartile
# author-react_pm-13-median
# identity_pm-13-mean
# scorm-fe_pm-16-thirdquartile
# scorm-fe_gm-9-min
# node-quantile:kubelet-pleg-relist-duration-seconds:histogram-quantile_pm-39-firstquartile
# ztool_pm-13-min
# ui_gm-9-max
# alms-core-scorm_pm-24-min
# acmesolver_pm-15-max
# rabbitmq_pm-13-mean
# identityapi_gm-9-thirdquartile
# ui_gm-7-firstquartile
# rui_gm-9-min
# scorm-fe_gm-11-mean
# redis_gm-19-firstquartile
# identity_pm-13-min
# instance-device:node-disk-io-time-seconds:rate5m_pm-21-firstquartile
# scorm-fe_pm-14-min
# alms-core-userhandlers_pm-22-median
# userhandlers_pm-13-min
# learner_gm-7-max
# acmesolver_pm-13-firstquartile
# alms-core-mail-sender_gm-50-max
# scormhandlers_pm-13-min
# scorm-fe_gm-7-median
# rui_gm-11-min
# ui_pm-16-median
# gradeservice_pm-13-max
# alms-core-author_pm-22-median
# fileapi_gm-21-firstquartile
# fileapi_gm-21-mean
# rui_gm-9-mean
# gradeservice_gm-9-thirdquartile
# userapi_gm-21-mean
# scorm-fe_pm-13-thirdquartile
# author-react_gm-11-median
# ui_pm-16-mean
# scorm-fe_gm-17-min
# rui_pm-13-min
# mail-sender_gm-17-mean
# mail-sender_pm-13-max
# alms-core-mail-sender_gm-50-mean
# ui_gm-17-mean
# author_gm-9-thirdquartile
# redis_pm-13-firstquartile
# alms-core-mail-sender_gm-51-min
# author-react_gm-7-max
# author_gm-7-max
# scorm-fe_pm-14-max
# rui_gm-9-median
# author_pm-14-thirdquartile
# instance-device:node-disk-io-time-seconds:rate5m_pm-21-mean
# ui_gm-9-min
# rui_gm-7-max
# identity_pm-14-median
# ztool_gm-21-mean
# identity_pm-14-firstquartile
# author_pm-13-thirdquartile
# fileapi_gm-21-median
# userapi_pm-14-mean
# scorm-fe_pm-16-max
# mail-sender_gm-21-max
# identityapi_gm-9-mean
# author_pm-15-firstquartile
# ui_pm-13-thirdquartile
# learner_gm-11-firstquartile
# author-react_pm-13-mean
# scorm-fe_gm-11-firstquartile
# rabbitmq_gm-21-max
# gradeservice_gm-21-thirdquartile
# scorm-fe_gm-21-min
# acmesolver_pm-8-count
# acmesolver_pm-5-mean
# learner_gm-7-firstquartile
# alms-core-learner_pm-24-max
# alms-core-author-react_pm-22-median
# author-react_gm-17-firstquartile
# scormhandlers_pm-14-max
# node-quantile:kubelet-pleg-relist-duration-seconds:histogram-quantile_pm-39-mean
# userhandlers_pm-14-mean
# ui_gm-17-thirdquartile
# author-react_gm-21-mean
# author_pm-13-firstquartile
# gradeservice_pm-13-firstquartile
# alms-core-scorm_pm-22-firstquartile
# mail-sender-web_pm-13-thirdquartile
# rabbitmq_gm-16-median
# acmesolver_pm-6-max
# rui_gm-7-thirdquartile
# userapi_pm-14-median
# rabbitmq_gm-21-mean
# scorm_pm-14-thirdquartile
# ztool_gm-9-max
# redis_gm-19-median
# alms-core-mail-sender_gm-51-max
# mail-sender_gm-21-firstquartile
# scormhandlers_gm-9-thirdquartile
# rui_gm-11-thirdquartile
# rui_pm-13-thirdquartile
# author_gm-17-max
# userhandlers_pm-13-median
# acmesolver_pm-14-min
# gradeservice_pm-14-mean
# alms-core-ztool_pm-24-thirdquartile
# alms-core-scormhandlers_pm-22-firstquartile
# acmesolver_pm-14-firstquartile
# author_gm-7-median
# mail-sender_gm-17-median
# author-react_gm-7-min
# author-react_gm-11-firstquartile
# scorm-fe_pm-15-min
# learner_pm-16-mean
# userhandlers_pm-13-firstquartile
# acmesolver_pm-6-mean
# learner_gm-9-thirdquartile
# instance-device:node-disk-io-time-seconds:rate5m_pm-21-median
# scorm-fe_gm-21-max
# identity_pm-14-min
# redis_pm-13-thirdquartile
# acmesolver_pm-15-mean
# rui_gm-11-median
# rabbitmq_gm-16-thirdquartile
# author_gm-11-thirdquartile
# learner_gm-9-max
# rui_gm-21-firstquartile
# author_pm-13-max
# mail-sender_gm-7-median
# mail-sender_gm-17-max
# scorm_pm-14-median
# author_pm-14-median
# gradeservice_gm-9-min
# author_gm-7-firstquartile
# instance:node-network-receive-drop-excluding-lo:rate5m_pm-19-median
# ui_gm-17-min
# alms-core-learner_pm-24-min
# author_pm-16-firstquartile
# author-react_gm-7-mean
# rui_gm-11-firstquartile
# redis_gm-19-thirdquartile
# alms-core-mail-sender_gm-51-median
# mail-sender_gm-7-mean
# scorm-fe_pm-16-mean
# mail-sender-web_pm-14-max
# learner_gm-11-min
# scorm_pm-14-min
# redis_gm-19-mean
# fileapi_gm-21-thirdquartile
# identityapi_pm-13-min
# fileapi_pm-14-min
# ui_pm-15-median
# gradeservice_gm-21-median
# author-react_gm-9-median
# ztool_gm-21-max
# acmesolver_pm-16-count
# userapi_pm-13-mean
# ui_pm-14-min
# identityapi_gm-9-max
# ztool_pm-13-max
# learner_gm-21-firstquartile
# author-react_gm-9-mean
# scormhandlers_gm-21-max
# author_pm-15-mean
# scorm-fe_pm-14-median
# acmesolver_pm-16-min
# scorm-fe_pm-16-min
# gradeservice_gm-9-mean
# redis_gm-19-max
# author-react_gm-21-max
# author-react_pm-14-thirdquartile
# scorm-fe_gm-7-max
# ui_pm-13-mean
# alms-core-fileapi_pm-22-median
# mail-sender_gm-21-mean
# scorm_gm-21-median
# mail-sender-web_pm-14-thirdquartile
# mail-sender_gm-17-firstquartile
# acmesolver_pm-6-min
# acmesolver_pm-14-thirdquartile
# ztool_gm-9-thirdquartile
# alms-core-author-react_pm-22-firstquartile
# mail-sender-web_gm-21-min
# gradeservice_gm-21-firstquartile
# scorm-fe_gm-21-mean
# acmesolver_pm-4-thirdquartile
# learner_gm-21-max
# alms-core-rui_pm-24-max
# learner_pm-13-firstquartile
# rabbitmq_gm-16-mean
# scorm-fe_gm-9-mean
# scorm_gm-21-mean
# rabbitmq_gm-21-firstquartile
# fileapi_pm-14-median
# rui_gm-9-firstquartile
# identityapi_pm-13-thirdquartile
# rabbitmq_gm-21-median
# acmesolver_pm-7-min
# gradeservice_gm-16-min
# fileapi_gm-21-min
# author_pm-15-max
# acmesolver_pm-4-firstquartile
# rui_gm-7-min
# fileapi_pm-14-max
# ui_pm-14-max
# acmesolver_pm-8-mean
# scorm-fe_gm-9-firstquartile
# ui_gm-9-thirdquartile
# scorm_pm-13-median
# userhandlers_pm-14-firstquartile
# alms-core-ui_pm-24-mean
# author_gm-17-thirdquartile
# gradeservice_gm-21-max
# author-react_gm-21-min
# scormhandlers_pm-13-thirdquartile
# scormhandlers_gm-19-firstquartile
# acmesolver_pm-4-max
# acmesolver_pm-15-count
# alms-core-ui_pm-24-median
# acmesolver_pm-13-max
# mail-sender-web_gm-21-firstquartile
# scormhandlers_gm-9-firstquartile
# rui_gm-21-median
# ui_gm-11-max
# author_pm-13-median
# ui_pm-13-max
# ui_pm-13-firstquartile
# redis_gm-21-firstquartile
# author_pm-16-thirdquartile
# instance:node-network-receive-drop-excluding-lo:rate5m_pm-19-min
# acmesolver_pm-8-thirdquartile
# rabbitmq_gm-19-min
# ui_gm-7-mean
# scorm-fe_gm-17-max
# rui_gm-11-max
# acmesolver_pm-13-median
# alms-core-scorm-fe_pm-22-firstquartile
# alms-core-gradeservice_pm-22-min
# ui_gm-11-median
# alms-core-ztool_pm-24-mean
# alms-core-userapi_pm-22-min
# rui_gm-17-mean
# scormhandlers_pm-13-median
# alms-core-scorm_pm-24-max
# ui_gm-11-min
# author-react_pm-14-max
# learner_pm-14-firstquartile
# ui_gm-9-median
# author_gm-17-mean
# userapi_gm-21-median
# alms-core-identity_pm-22-firstquartile
# author_gm-21-max
# author_pm-14-mean
# alms-core-userapi_pm-22-firstquartile
# alms-core-author_pm-22-firstquartile
# acmesolver_pm-13-min
# userapi_pm-14-firstquartile
# alms-core-mail-sender_gm-50-firstquartile
# fileapi_pm-14-thirdquartile
# scorm_gm-16-min
# author_gm-21-median
# ztool_gm-21-median
# author_pm-14-firstquartile
# author-react_gm-9-firstquartile
# scorm-fe_gm-11-median
# ztool_pm-15-mean
# alms-core-rui_pm-24-thirdquartile
# identity_pm-13-firstquartile
# identityapi_pm-15-max
# author_pm-16-median
# node-quantile:kubelet-pleg-relist-duration-seconds:histogram-quantile_pm-39-thirdquartile
# fileapi_pm-13-thirdquartile
# ztool_pm-15-median
# ui_gm-7-min
# rui_pm-13-max
# mail-sender-web_pm-14-min
# alms-core-learner_pm-22-median
# ui_gm-7-median
# alms-core-mail-sender_gm-51-firstquartile
# scorm_pm-13-max
# learner_gm-7-min
# alms-core-scorm_pm-24-median
# identityapi_pm-13-firstquartile
# rui_gm-17-max
# alms-core-learner_pm-24-thirdquartile
# alms-core-rui_pm-22-median
# alms-core-identityapi_pm-22-firstquartile
# rabbitmq_gm-19-thirdquartile
# scorm-fe_pm-13-firstquartile
# instance:node-network-receive-drop-excluding-lo:rate5m_pm-19-firstquartile
# gradeservice_gm-17-min
# scormhandlers_pm-13-mean
# alms-core-learner_pm-24-firstquartile
# author_gm-9-median
# scorm-fe_gm-11-min
# author_gm-17-firstquartile
# scorm-fe_pm-13-median
# author-react_gm-11-max
# ui_gm-11-firstquartile
# ui_gm-21-median
# alms-core-mail-sender-web_pm-22-median
# acmesolver_pm-7-count
# mail-sender_gm-17-thirdquartile
# redis_gm-16-max
# acmesolver_pm-14-median
# alms-core-ui_pm-24-firstquartile
# scorm-fe_pm-14-firstquartile
# alms-core-ui_pm-22-median
# alms-core-userhandlers_pm-22-min
# ztool_pm-14-mean
# author-react_gm-9-thirdquartile
# scormhandlers_gm-21-firstquartile
# mail-sender_pm-13-mean
# acmesolver_pm-5-median
# acmesolver_pm-14-mean
# ui_pm-14-mean
# author-react_gm-17-mean
# scorm_pm-14-max
# fileapi_pm-13-median
# learner_gm-9-mean
# acmesolver_pm-7-thirdquartile
# alms-core-mail-sender_gm-51-mean
# scorm-fe_pm-13-max
# scormhandlers_gm-9-mean
# ztool_gm-21-firstquartile
# rabbitmq_gm-21-min
# author-react_gm-9-min
# learner_pm-13-min
# mail-sender_pm-13-min
# alms-core-identityapi_pm-22-median
# scorm_gm-21-min
# acmesolver_pm-8-firstquartile
# alms-core-ui_pm-22-min
# learner_gm-21-min
# ui_pm-13-median
# gradeservice_gm-9-median
# author-react_pm-13-min
# fileapi_pm-14-mean
# mail-sender-web_pm-14-firstquartile
# redis_pm-13-min
# identityapi_pm-13-max
# alms-core-scorm_pm-24-thirdquartile
# redis_gm-16-thirdquartile
# rui_gm-7-median
# alms-core-ztool_pm-24-min
# mail-sender-web_gm-21-max
# identityapi_pm-14-min
# author_gm-21-firstquartile
# alms-core-mail-sender_gm-50-thirdquartile
# learner_pm-13-max
# learner_pm-16-thirdquartile
# author_gm-11-max
# identityapi_pm-13-mean
# scormhandlers_pm-14-firstquartile
# alms-core-gradeservice_pm-22-median
# learner_gm-7-mean
# rui_gm-17-min
# author-react_gm-21-firstquartile
# rui_pm-16-median
# mail-sender-web_gm-21-mean
# rui_pm-14-thirdquartile
# instance:node-network-receive-drop-excluding-lo:rate5m_pm-19-max
# ui_pm-14-firstquartile
# ui_gm-7-thirdquartile
# gradeservice_pm-13-mean
# alms-core-ui_pm-24-thirdquartile
# learner_gm-21-thirdquartile
# scormhandlers_pm-13-max
# author-react_gm-17-min
# ui_gm-21-max
# acmesolver_pm-13-thirdquartile
# author-react_gm-7-thirdquartile
# author_gm-17-median
# acmesolver_pm-6-median
# author-react_gm-21-median
# ui_pm-16-max
# acmesolver_pm-6-count
# rui_gm-17-median
# scorm_gm-17-min
# userapi_gm-21-firstquartile
# userhandlers_pm-14-min
# rui_pm-13-firstquartile
# scorm_pm-13-min
# identityapi_pm-14-firstquartile
# rabbitmq_gm-19-firstquartile
# alms-core-identity_pm-22-min
# redis_gm-21-thirdquartile
# author-react_gm-9-max
# alms-core-rui_pm-22-firstquartile
# acmesolver_pm-7-firstquartile
# userapi_pm-13-max
# gradeservice_pm-13-thirdquartile
# rui_pm-14-min
# author-react_gm-17-thirdquartile
# author_pm-16-max
# node-quantile:kubelet-pleg-relist-duration-seconds:histogram-quantile_pm-39-median
# alms-core-scormhandlers_pm-22-min
# redis_gm-21-max
# gradeservice_pm-13-median
# gradeservice_pm-14-thirdquartile
# alms-core-mail-sender-web_pm-22-min
# acmesolver_pm-6-firstquartile
# redis_gm-21-median
# ztool_pm-13-thirdquartile
# identityapi_pm-13-median
# scorm-fe_gm-9-thirdquartile
# rui_pm-14-firstquartile
# userhandlers_pm-14-median
# acmesolver_pm-14-count
# mail-sender_gm-21-thirdquartile
# scorm-fe_pm-15-mean
# acmesolver_pm-13-mean
# learner_pm-16-min
# scormhandlers_gm-9-min
# acmesolver_pm-5-count
# rabbitmq_pm-13-median
# alms-core-mail-sender_gm-50-min
# author-react_gm-7-median
# scorm-fe_pm-13-min
# alms-core-learner_pm-24-median
# ui_gm-21-mean
# author_gm-7-thirdquartile
# alms-core-author_pm-22-min
# acmesolver_pm-16-firstquartile
# mail-sender-web_gm-21-thirdquartile
# author_gm-9-max
# scorm_pm-13-mean
# identity_pm-14-thirdquartile
# alms-core-learner_pm-22-min
# acmesolver_pm-15-firstquartile
# redis_gm-17-min
# userapi_gm-21-thirdquartile
# ztool_pm-14-median
# scorm_pm-13-thirdquartile

# %%
# -- Drop the columns that do not contain service name or kube node name
# We don't do it

if DROP_KPIS_WITH_UNKNOWN_NODES:
    print(DROP_KPIS_WITH_UNKNOWN_NODES)
    
    columns_to_drop = []
    for column_name in list(train_data_df.columns):
        resource_name = column_name.split("_")[0]
        if (resource_name not in LMS_SERVICE_LIST) and (resource_name[:4] not in KUBE_NODE_LIST):
            columns_to_drop.append(column_name)
            
    train_data_df.drop(columns=columns_to_drop, inplace=True)
    for ii in range(len(prod_data_dfs)):
        prod_data_dfs[ii].drop(columns=columns_to_drop, inplace=True)

# %%
# -- Drop locust metrics
# We don't do it

if DROP_LOCUST_KPIS:
    print(DROP_LOCUST_KPIS)

    columns_to_drop = [column_name for column_name in list(train_data_df.columns) if column_name.split("_")[0] == locust_node_name]
    
    train_data_df.drop(columns=columns_to_drop, inplace=True)
    for ii in range(len(prod_data_dfs)):
        prod_data_dfs[ii].drop(columns=columns_to_drop, inplace=True)

# %%
# -- Drop the columns of the extended set
# We don't do it

if DROP_EXTENDED_KPI_SET:
    print(DROP_EXTENDED_KPI_SET)
    
    train_data_df = drop_columns_by_filter(train_data_df, set_of_kpis_to_drop)
    for ii in range(len(prod_data_dfs)):
        prod_data_dfs[ii] = drop_columns_by_filter(prod_data_dfs[ii], set_of_kpis_to_drop)

# %%
# -- Apply the first order differencing to all collumns
# We don't do it

if APPLY_DIFFERENCING:
    print(APPLY_DIFFERENCING)
    
    if kpis_to_apply_differencing == "all":
        kpis_to_apply_differencing = list(train_data_df.columns)
    else:
        kpis_to_apply_differencing = kpis_to_apply_differencing.split(",")

    # For the training data set
    for idx, col in enumerate(train_data_df.columns):
        if col in kpis_to_apply_differencing and col != column_name_number_of_users:
            train_data_df[col] = difference_order(train_data_df[col], 1, 1)

    # For the production data sets
    for ii in range(len(prod_data_dfs)):
        for idx, col in enumerate(prod_data_dfs[ii].columns):
            if col in kpis_to_apply_differencing and col != column_name_number_of_users:
                prod_data_dfs[ii][col] = difference_order(prod_data_dfs[ii][col], 1, 1)

# %%
# -- Keep only the service related KPIs
# We don't do it

if KEEP_ONLY_SERVICE_RELATED_KPIS:
    print(KEEP_ONLY_SERVICE_RELATED_KPIS)

    columns_to_drop = [column_name for column_name in list(train_data_df.columns) if column_name.split("_")[0] not in app_service_list]
    
    train_data_df.drop(columns=columns_to_drop, inplace=True)
    for ii in range(len(prod_data_dfs)):
        prod_data_dfs[ii].drop(columns=columns_to_drop, inplace=True)

# %%
# Detect & Remove up outliers for the predefined set of KPIs from the Training data set
# We don't do it

if REMOVE_OUTLIERS:
    print(REMOVE_OUTLIERS)

    for kpi in list(train_data_df.columns):

        if "count" in kpi:
            continue

        Q1 = np.percentile(train_data_df[kpi], 25, method='midpoint')
        Q3 = np.percentile(train_data_df[kpi], 75, method='midpoint')
        Q95 = np.percentile(train_data_df[kpi], 95, method='midpoint')
        
        # IQR = Q3 - Q1
        # upper = Q3 + 1.5 * IQR
        # lower = Q1 - 1.5 * IQR
        upper = Q95

        upper_array = np.where(train_data_df[kpi] >= upper)[0]
        # lower_array = np.where(train_data_df[kpi] <= lower)[0]

        train_data_df.drop(index=upper_array, inplace=True, errors='ignore')
        # train_data_df.drop(index=lower_array, inplace=True, errors='ignore')
        
    
    print(train_data_df.shape)

# %%
# -- Save data sets

# Create a target folder if does not exist
create_dir(tuned_data_set_dir_path)

# Save the training data set
train_data_df.to_csv(tuned_data_set_file_path.format(data_set_code=train_data_set_code), encoding='utf-8', index=False, header=True)
print("Train DF saved", train_data_df.shape)

# Save the prod data sets
for ii in range(len(prod_data_dfs)):
    data_set_code = prod_data_set_codes[ii]
    df_tmp = prod_data_dfs[ii]
    df_tmp.to_csv(tuned_data_set_file_path.format(data_set_code=data_set_code), encoding='utf-8', index=False, header=True)
    
    print("{data_set_code} DF Saved. Shape: ".format(data_set_code=data_set_code), df_tmp.shape)
# Out:
# Train DF saved (14514, 3948)
# linear-cpu-stress-userapi-051516 DF Saved. Shape:  (181, 3948)
# linear-cpu-stress-redis-091514 DF Saved. Shape:  (151, 3948)
# linear-memory-stress-userapi-051218 DF Saved. Shape:  (181, 3948)
# linear-memory-stress-redis-091522 DF Saved. Shape:  (151, 3948)
# linear-network-delay-userapi-051816 DF Saved. Shape:  (180, 3948)
# linear-network-delay-redis-092016 DF Saved. Shape:  (151, 3948)
# linear-cpu-stress-identity-100410 DF Saved. Shape:  (151, 3948)
# linear-cpu-stress-userhandlers-100517 DF Saved. Shape:  (151, 3948)
# linear-memory-stress-identity-100414 DF Saved. Shape:  (151, 3948)
# linear-memory-stress-userhandlers-100609 DF Saved. Shape:  (151, 3948)
